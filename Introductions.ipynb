# %% [markdown]
# # **Notebook 0:** Introductions
#
# [wdtmacss@berkeley.edu](mailto:wdtmacss@berkeley.edu)\
# **Computational Social Science 1A** [Human Psychology and Social Technologies](https://classes.berkeley.edu/content/2024-fall-compss-214a-001-lec-001) Fall 2024\
# UC Berkeley [Masters in Computational Social Science](https://macss.berkeley.edu/about/)
#
# **Week 1:** Welcome! Introductions, class logistics, course schedule and assignments overview.
#
# 🥳🥳🥳
#
# ---
# **Table of Contents**
#
# >[Class Summary](#scrollTo=_a-AARYW-hC_)
#
# >[Introductions](#scrollTo=N2oIPAuXzgUN)
#
# >>[Instructor](#scrollTo=GyVkqW6cxjHW)
#
# >>[Teaching Assistant](#scrollTo=GmrEB5RT0aA3)
#
# >>[Class Introductions](#scrollTo=8b6vcfGF0Z-x)
#
# >[Course Overview](#scrollTo=lQtVC2se0Z8L)
#
# >>[Logistics](#scrollTo=lQtVC2se0Z8L)
#
# >>>[Time & Place](#scrollTo=lQtVC2se0Z8L)
#
# >>>[Syllabus & Bcourses](#scrollTo=lQtVC2se0Z8L)
#
# >>>[Communications](#scrollTo=lQtVC2se0Z8L)
#
# >>>[Office Hours & Sections](#scrollTo=lQtVC2se0Z8L)
#
# >>[Programming logistics](#scrollTo=gzjfb4FK74Kv)
#
# >>[Schedule & Course Content](#scrollTo=Whv97nWa0Zur)
#
# >[Assignments and Grading](#scrollTo=sgGVdcy7_do2)
#
# >>[Assignment 1](#scrollTo=sgGVdcy7_do2)
#
# >>[Assignments 2 and 3](#scrollTo=sgGVdcy7_do2)
#
# >>[Assignment 4](#scrollTo=sgGVdcy7_do2)
#
# >[Today's Exercise](#scrollTo=qIMGUH4gA2wf)
#
# >[Required Reading](#scrollTo=WbNQJB3KDjWV)

# %% [markdown]
# # Class Summary
# We will focus on social media data, and how insights and methods from Psychology and Cognitive Science can help us make sense of the complex datasets that are generated by human behavior on large-scale social media platforms. Part one will focus on [Misinformation on Twitter](https://www.nature.com/articles/s41586-024-07524-8). Part Two will focus on [real world decision-making on Reddit](https://osf.io/preprints/psyarxiv/hzv7c). We will analyze datasets using Python.

# %% [markdown]
# # Introductions
# Welcome to [Computational Social Science 1A](https://classes.berkeley.edu/content/2024-fall-compss-214a-001-lec-001).

# %% [markdown]
# ## Instructor
#
# *   **Name:** William (Bill) Thompson
# *   **Pronouns:** He/Him/They
# *   **Email:** wdtmacss@berkeley.edu
# *   **About me**
#     * I am an [Assistant Professor in the Department of Psychology and the Program in Cognitive Science](https://billdthompson.github.io/) here at UC Berkeley.
#     * I am director of the Computational Cognitive Science Lab, a reearch group studying reasoning and conceptualization in humans and AI systems.
#     * One of the goals of my research is to develop improved methods for analyzing human behavior at scale, by drawing on the theories and computational tools developed in cognitive science.

# %% [markdown]
# ## Teaching Assistant
#
# * **Name:** Tejasvi (Teja) Kalakota
# * **Email:** tejasvi.kalakota@berkeley.edu

# %% [markdown]
# ## Class Introductions

# %% [markdown]
# # Course Overview
# ## Logistics
# Some logistical details below. You can always email me (wdtmacss@berkeley.edu) or Teja (tejasvi.kalakota@berkeley.edu) with questions =)
#
# ### Time & Place
#
# *   Fridays 2pm - 5pm
# *   2121 Allston Way (MaCSS Space)
# *   Friday August 30th -- Friday October 11th (7 weeks)
#
#
#
# ### Syllabus & Bcourses
#
# *   The Bcourses site for this course is here: https://bcourses.berkeley.edu/courses/1538139
# * Everyone should be enrolled on the Bcourses site already -- let me know if you are not
# * The latest draft of **[the Syllabus for this course](https://bcourses.berkeley.edu/courses/1538139/files/89484354) will always be linked on the home page of the Bcourses site** and also accessible in the Files section.
#     * Note: the syllabus will likely evolve over time\\
# * The latest draft of the syllabus is your go-to source for information about the course.
#
# ### Communications
#
# *  I will send **announcements through BCourses** (let's do a test right now).
# *  You are welcome to email me any time with questions, but I always warn students that I get a lot more emails than I can possible answer every day, so at some points in the semester I am only able to respond to urgent matters 🥲 thanks in advance for your patience and understanding 🙏
# *  Suggested information-seeking hierarchy: first check the syllabus, then ask your fellow students, then email Teja, then email me.
#
# ### Office Hours & Sections
# TBD

# %% [markdown]
# ## Programming logistics
#
# *   This course is lab-based and exclusively taught in **Python**
# *   We will use Jupyter notebooks like this one, hosted in the Github repository for this course and accessed through UC Berkeley Datahub.
#
# **Goal:** Open this notebook through your Datahub enviornment.

# %% [markdown]
# ## Schedule & Course Content
# Let's look through the [course syllabus](https://bcourses.berkeley.edu/courses/1538139/files/89484354) together.

# %% [markdown]
# # Assignments and Grading
#
# ## Assignment 1
# * Short context exercise (more below)
# * 10% of grade (Complete/Incomplete)
#
# ## Assignments 2 and 3
# * Small data analysis projects wrapping up your work in parts one and two
# * 70% of your grade
# * I will provide a full grading rubric for these assignments
#
# ## Assignment 4
# * Short reflection exercise
# * 10% of your grade (complete/incomplete)

# %% [markdown]
# # Today's Exercise
# **Assignment 1.**
#
# **Instructions:**
# *   Complete function below
# *   Run cell XYZ that calls the function
# *   Download a copy of this notebook
# *   Upload your notebook for Assignment 1 in Bcourses.
#
#
# **Grading**
# Your assignment will be graded as complete if you submit a notebook in which the code cell X runs and produces Y.

# %%
def function(arg1, arg2):
  """
  Args:
  - arg1: xyz
  - arg2: xyz

  Objective: this function should do ABC.

  Returns: a string describing Z.
  """
  answer = "Not implemented"
  return answer

# %%
result = function(arg1="x", arg2="y")
print(result)
# Out:
# Not implemented

# %% [markdown]
# # Required Reading
# **Before** the next class you must read this paper **very carefully and comprehensively**:
#
# [Post-January 6th deplatforming reduced the reach of misinformation on Twitter](https://www.nature.com/articles/s41586-024-07524-8)
#
# You can access a pdf of the article [here on BCourses](https://bcourses.berkeley.edu/courses/1538139/files/89496953)
#
# *   Your goal is to read this research article in full very thoroughly, **including the Methods section** at the end of the article.
# *   Next Friday we will **discuss this article as a class**
# *   **You will be asked to answer questions about the article**, and **the dataset described within the article will be our focus for the next three weeks** and the basis for Assignment 2.
#
# Please also **listen to this assosciated [podcast episode](https://www.youtube.com/watch?v=Ng-cy1ynqBA)**
